# %% [markdown]
# # 03 — Operações geométricas
#
# Soma corresponde à soma vetorial. Multiplicação, na forma polar, combina escala e rotação.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))
import numpy as np
import matplotlib.pyplot as plt
from src.complex_geometry import plot_complex, rotate

z = 1 + 1j
z_rot = rotate(z, np.pi/2)

fig, ax = plt.subplots(figsize=(6,6))
plot_complex(z, label='z', ax=ax, limits=(-2.5, 2.5))
plot_complex(z_rot, label='i·z', ax=ax, limits=(-2.5, 2.5))
plt.show()

# %% [markdown]
# ## Questão
#
# Por que multiplicar por $i=e^{i\pi/2}$ equivale a uma rotação de $90^\circ$?
