# %% [markdown]
# # 01 — Plano complexo
#
# Objetivo: interpretar $z=a+bi$ como ponto/vetor $(a,b)$.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))
import matplotlib.pyplot as plt
from src.complex_geometry import plot_complex

z = 3 + 4j
plot_complex(z, label='z')
plt.show()

# %% [markdown]
# ## Exercício
#
# Altere `z` para $1+i$, $-2+i$ e $2-3i$. Antes de executar, preveja o quadrante.
